# %% [markdown]
# <a href="https://colab.research.google.com/github/MingzheSun/APS360GP/blob/main/main_test_git.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
from glob import glob
import os
import pandas
import matplotlib.pyplot as plt
import matplotlib
import pathlib

# %%
# !pip install mne
# Out:
# ...
#      |████████████████████████████████| 7.5 MB 1.8 MB/s
# ...

# %%
# 0 Awake
# 1 NREM stage 1
# 2 NREM stage 2
# 3 NREM stage 3 and 4
# 4 REM
# 5 Movement time ?

from mne.annotations import events_from_annotations
import mne
from mne.io import concatenate_raws, read_raw_edf
import matplotlib.pyplot as plt
import mne

# %%
file = "/content/drive/MyDrive/Research/SS2.edf/01-02-0001 Base.edf"
#file = "/content/drive/MyDrive/Research/SS2.edf/01-02-0001 PSG.edf"
#file = "/content/drive/MyDrive/Research/S5 annotations /01-05-0001 Annotations.edf"

raw = mne.io.read_raw_edf(file)
events_from_annot, event_dict = mne.events_from_annotations(raw)
print("RAW_INFO")
print(raw.info)
print("RAW_INFO")
#custom_mapping = {'Sleep stage 1': 1, 'Sleep stage 2': 2, 'Sleep stage 3': 3, 'Sleep stage 4': 4, 'Sleep stage ?': 5, 'Sleep stage R': 6, 'Sleep stage W': 7}
(events_from_annot,event_dict) = mne.events_from_annotations(raw)
print(event_dict)
print(events_from_annot)

fig = mne.viz.plot_events(events_from_annot, sfreq=raw.info['sfreq'],
                          first_samp=raw.first_samp, event_id=event_dict)
fig.subplots_adjust(right=0.7)
# Out:
# Extracting EDF parameters from /content/drive/MyDrive/Research/SS2.edf/01-02-0001 Base.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage ?', 'Sleep stage R', 'Sleep stage W']
# RAW_INFO
# <Info | 5 non-empty values
#  bads: []
#  ch_names: []
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 7.0 Hz
#  meas_date: 2000-01-01 23:00:59 UTC
#  nchan: 0
#  projs: []
#  sfreq: 14.0 Hz
# >
# RAW_INFO
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage ?', 'Sleep stage R', 'Sleep stage W']
# {'Sleep stage 1': 1, 'Sleep stage 2': 2, 'Sleep stage 3': 3, 'Sleep stage 4': 4, 'Sleep stage ?': 5, 'Sleep stage R': 6, 'Sleep stage W': 7}
# [[  7855      0      5]
#  [  8135      0      5]
#  [  8415      0      5]
#  ...
#  [404360      0      7]
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.pipeline import Pipeline
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.model_selection import ShuffleSplit, cross_val_score

from mne import Epochs, pick_types, events_from_annotations
from mne.channels import make_standard_montage
from mne.io import concatenate_raws, read_raw_edf
from mne.datasets import eegbci
from mne.decoding import CSP
#file = "/content/drive/MyDrive/Research/SS2.edf/01-02-0001 Base.edf"
file = "/content/drive/MyDrive/Research/SS2.edf/01-02-0001 PSG.edf"
#file = "/content/drive/MyDrive/Research/S5 annotations /01-05-0001 Annotations.edf"

raw = mne.io.read_raw_edf(file)
events_from_annot, event_dict = mne.events_from_annotations(raw)
print("RAW_INFO")
print(raw.info)
print(raw.info.ch_names)
print(raw.get_data)
print("RAW_INFO")
raw.plot(duration=5,n_channels=27,clipping=None)
raw.plot_psd(average=True)
"""
custom_mapping = {'EEG Fp1-CLE:1',                  'EEG Fp2-CLE:2',
                   'EEG F3-CLE:3',
                   'EEG F4-CLE:4',
                   'EEG F7-CLE:5',
                   'EEG F8-CLE:6',
                   'EEG C3-CLE:7',
                   'EEG C4-CLE:8',
                   'EEG P3-CLE:9',
                   'EEG P4-CLE:10',
                   'EEG O1-CLE:11',
                   'EEG O2-CLE:12',
                   'EEG T3-CLE:13',
                   'EEG T4-CLE:14', 
                   'EEG T5-CLE:15', 
                   'EEG T6-CLE:16',
                   'EEG Fpz-CLE:17',
                   'EEG Cz-CLE:18',
                   'EEG Pz-CLE:19', 
                   'EOG Upper Vertic:20', 
                   'EOG Lower Vertic:21',
                   'EOG Left Horiz:22',
                   'EOG Right Horiz:23',
                   'EMG Chin:24',
                   'ECG ECGI:25',
                   'Resp Nasal:26',
                   'EEG A2-CLE:27'
}

(events_from_annot,event_dict) = mne.events_from_annotations(raw,event_id=custom_mapping)
print(event_dict)
print(events_from_annot)
picks = pick_types(raw.info, meg=False, eeg=True, stim=False, eog=False,
                   exclude='bads')
print(picks)
tmin, tmax = -1, 4
event_ids = dict(hands=2, feet=3)  # map event IDs to tasks

epochs = mne.Epochs(raw, events_from_annot, event_dict, tmin - 0.5, tmax + 0.5,
                     baseline=None, preload=True)
"""
# Out:
# Extracting EDF parameters from /content/drive/MyDrive/Research/SS2.edf/01-02-0001 PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# RAW_INFO
# <Info | 7 non-empty values
#  bads: []
#  ch_names: EEG Fp1-CLE, EEG Fp2-CLE, EEG F3-CLE, EEG F4-CLE, EEG F7-CLE, ...
#  chs: 27 EEG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 128.0 Hz
#  meas_date: 2000-01-01 23:00:59 UTC
#  nchan: 27
#  projs: []
#  sfreq: 256.0 Hz
# >
# ['EEG Fp1-CLE', 'EEG Fp2-CLE', 'EEG F3-CLE', 'EEG F4-CLE', 'EEG F7-CLE', 'EEG F8-CLE', 'EEG C3-CLE', 'EEG C4-CLE', 'EEG P3-CLE', 'EEG P4-CLE', 'EEG O1-CLE', 'EEG O2-CLE', 'EEG T3-CLE', 'EEG T4-CLE', 'EEG T5-CLE', 'EEG T6-CLE', 'EEG Fpz-CLE', 'EEG Cz-CLE', 'EEG Pz-CLE', 'EOG Upper Vertic', 'EOG Lower Vertic', 'EOG Left Horiz', 'EOG Right Horiz', 'EMG Chin', 'ECG ECGI', 'Resp Nasal', 'EEG A2-CLE']
# <bound method get_data of <RawEDF | 01-02-0001 PSG.edf, 27 x 7412736 (28956.0 s), ~31 kB, data not loaded>>
# ...

# %%
#file = "/content/drive/MyDrive/Research/SS2.edf/01-02-0001 Base.edf"
#file = "/content/drive/MyDrive/Research/SS2.edf/01-02-0001 PSG.edf"
file = "/content/drive/MyDrive/Research/SS2_Annotations/Spindles_E1/01-02-0001 Spindles_E1.edf"

raw = mne.io.read_raw_edf(file)
events_from_annot, event_dict = mne.events_from_annotations(raw)
print("RAW_INFO")
print(raw.info)
print("RAW_INFO")
#custom_mapping = {'Sleep stage 1': 1, 'Sleep stage 2': 2, 'Sleep stage 3': 3, 'Sleep stage 4': 4, 'Sleep stage ?': 5, 'Sleep stage R': 6, 'Sleep stage W': 7}
(events_from_annot,event_dict) = mne.events_from_annotations(raw)
print(event_dict)
print(events_from_annot)

fig = mne.viz.plot_events(events_from_annot, sfreq=raw.info['sfreq'],
                          first_samp=raw.first_samp, event_id=event_dict)
fig.subplots_adjust(right=0.7)
# Out:
# Extracting EDF parameters from /content/drive/MyDrive/Research/SS2_Annotations/Spindles_E1/01-02-0001 Spindles_E1.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['<Event channel="EEG C3-LER" groupName="spindle" name="spindleE1" scoringType="manual"/>']
# RAW_INFO
# <Info | 5 non-empty values
#  bads: []
#  ch_names: []
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 30.0 Hz
#  meas_date: 2000-01-01 23:00:59 UTC
#  nchan: 0
#  projs: []
#  sfreq: 60.0 Hz
# >
# RAW_INFO
# Used Annotations descriptions: ['<Event channel="EEG C3-LER" groupName="spindle" name="spindleE1" scoringType="manual"/>']
# {'<Event channel="EEG C3-LER" groupName="spindle" name="spindleE1" scoringType="manual"/>': 1}
# [[  53318       0       1]
#  [  54363       0       1]
#  [  55082       0       1]
#  ...
#  [1691193       0       1]
#  [1707087       0       1]
#  [1717494       0       1]]

# %%
#file = "/content/drive/MyDrive/Research/SS2.edf/01-02-0001 Base.edf"
#file = "/content/drive/MyDrive/Research/SS2.edf/01-02-0001 PSG.edf"
file = "/content/drive/MyDrive/Research/SS2_Annotations/KComplexes_E1/01-02-0001 KComplexes_E1.edf"

raw = mne.io.read_raw_edf(file)
events_from_annot, event_dict = mne.events_from_annotations(raw)
print("RAW_INFO")
print(raw.info)
print("RAW_INFO")
#custom_mapping = {'Sleep stage 1': 1, 'Sleep stage 2': 2, 'Sleep stage 3': 3, 'Sleep stage 4': 4, 'Sleep stage ?': 5, 'Sleep stage R': 6, 'Sleep stage W': 7}
(events_from_annot,event_dict) = mne.events_from_annotations(raw)
print(event_dict)
print(events_from_annot)

fig = mne.viz.plot_events(events_from_annot, sfreq=raw.info['sfreq'],
                          first_samp=raw.first_samp, event_id=event_dict)
# Out:
# Extracting EDF parameters from /content/drive/MyDrive/Research/SS2_Annotations/KComplexes_E1/01-02-0001 KComplexes_E1.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['<Event channel="EEG C3-LER" groupName="kcomplex" name="kComplexE1" scoringType="manual"/>']
# RAW_INFO
# <Info | 5 non-empty values
#  bads: []
#  ch_names: []
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 44.5 Hz
#  meas_date: 2000-01-01 23:00:59 UTC
#  nchan: 0
#  projs: []
#  sfreq: 89.0 Hz
# >
# RAW_INFO
# Used Annotations descriptions: ['<Event channel="EEG C3-LER" groupName="kcomplex" name="kComplexE1" scoringType="manual"/>']
# {'<Event channel="EEG C3-LER" groupName="kcomplex" name="kComplexE1" scoringType="manual"/>': 1}
# [[  73949       0       1]
#  [  74874       0       1]
#  [  86410       0       1]
#  ...
#  [2518958       0       1]
#  [2546344       0       1]
#  [2551517       0       1]]

# %%
#file = "/content/drive/MyDrive/Research/SS2.edf/01-02-0001 Base.edf"
#file = "/content/drive/MyDrive/Research/SS2.edf/01-02-0001 PSG.edf"
file = "/content/drive/MyDrive/Research/SS2_Annotations/01-02-0001 Base.edf"

raw = mne.io.read_raw_edf(file)
events_from_annot, event_dict = mne.events_from_annotations(raw)
print("RAW_INFO")
print(raw.info)
print("RAW_INFO")
#custom_mapping = {'Sleep stage 1': 1, 'Sleep stage 2': 2, 'Sleep stage 3': 3, 'Sleep stage 4': 4, 'Sleep stage ?': 5, 'Sleep stage R': 6, 'Sleep stage W': 7}
(events_from_annot,event_dict) = mne.events_from_annotations(raw)
print(event_dict)
print(events_from_annot)

fig = mne.viz.plot_events(events_from_annot, sfreq=raw.info['sfreq'],
                          first_samp=raw.first_samp, event_id=event_dict)
# Out:
# Extracting EDF parameters from /content/drive/MyDrive/Research/SS2_Annotations/01-02-0001 Base.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage ?', 'Sleep stage R', 'Sleep stage W']
# RAW_INFO
# <Info | 5 non-empty values
#  bads: []
#  ch_names: []
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 7.0 Hz
#  meas_date: 2000-01-01 23:00:59 UTC
#  nchan: 0
#  projs: []
#  sfreq: 14.0 Hz
# >
# RAW_INFO
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage ?', 'Sleep stage R', 'Sleep stage W']
# {'Sleep stage 1': 1, 'Sleep stage 2': 2, 'Sleep stage 3': 3, 'Sleep stage 4': 4, 'Sleep stage ?': 5, 'Sleep stage R': 6, 'Sleep stage W': 7}
# [[  7855      0      5]
#  [  8135      0      5]
#  [  8415      0      5]
#  ...
#  [404360      0      7]
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# !pip install pyedflib

import argparse
import glob
import math
import ntpath
import os
import shutil
import pyedflib
import numpy as np
import pandas as pd

# Required Libraries

import numpy as np
import torch
import torchvision
import matplotlib.pyplot as plt

import sklearn
from sklearn.svm import LinearSVC
from sklearn.svm import SVC

import torch.nn as nn
import torch.nn.functional as F
from torchvision import datasets, transforms
import matplotlib.pyplot as plt # for plotting
import torch.optim as optim
from sklearn.model_selection import train_test_split
from torchvision import datasets, models, transforms
import torchvision.transforms as transforms
from torch.utils.data.sampler import SubsetRandomSampler
from torch.utils.data import Dataset

import os
import torch
from torch import nn
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
device = "cuda" if torch.cuda.is_available() else "cpu"
use_cuda = True if torch.cuda.is_available() else False
use_cuda = True
print(f"Using {device} device")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ...
#      |████████████████████████████████| 2.4 MB 5.2 MB/s
# ...
# Using cpu device

# %%
ann_file = "/content/drive/MyDrive/Research/SS2.edf/01-02-0001 Base.edf"
psg_file = "/content/drive/MyDrive/Research/SS2.edf/01-02-0001 PSG.edf"

ann_dir = "/content/drive/MyDrive/Research/SS2.edf/"
psg_dir = "/content/drive/MyDrive/Research/SS2.edf/"
psg_fnames = glob.glob(os.path.join(psg_dir, "*PSG.edf"))
ann_fnames = glob.glob(os.path.join(ann_dir, "*Base.edf"))
psg_fnames.sort()
ann_fnames.sort()
psg_fnames = np.asarray(psg_fnames)
ann_fnames = np.asarray(ann_fnames)

print(ann_fnames)
# Out:
# ['/content/drive/MyDrive/Research/SS2.edf/01-02-0001 Base.edf'
#  '/content/drive/MyDrive/Research/SS2.edf/01-02-0002 Base.edf'
#  '/content/drive/MyDrive/Research/SS2.edf/01-02-0003 Base.edf'
#  '/content/drive/MyDrive/Research/SS2.edf/01-02-0004 Base.edf'
#  '/content/drive/MyDrive/Research/SS2.edf/01-02-0005 Base.edf'
#  '/content/drive/MyDrive/Research/SS2.edf/01-02-0006 Base.edf'
#  '/content/drive/MyDrive/Research/SS2.edf/01-02-0007 Base.edf'
#  '/content/drive/MyDrive/Research/SS2.edf/01-02-0008 Base.edf'
#  '/content/drive/MyDrive/Research/SS2.edf/01-02-0009 Base.edf'
#  '/content/drive/MyDrive/Research/SS2.edf/01-02-0010 Base.edf'
#  '/content/drive/MyDrive/Research/SS2.edf/01-02-0011 Base.edf'
#  '/content/drive/MyDrive/Research/SS2.edf/01-02-0012 Base.edf'
#  '/content/drive/MyDrive/Research/SS2.edf/01-02-0013 Base.edf'
#  '/content/drive/MyDrive/Research/SS2.edf/01-02-0014 Base.edf'
#  '/content/drive/MyDrive/Research/SS2.edf/01-02-0015 Base.edf'
# ...

# %%
select_ch = "EEG F4-CLE"
unknown_label = 'Sleep stage ?'
labeldict = {
  "Sleep stage W": 0,
  "Sleep stage 1": 1,
  "Sleep stage 2": 2,
  "Sleep stage 3": 3, 
  "Sleep stage 4": 3,
  "Sleep stage R": 4
}

dataset, label = [], []

for i in range(len(psg_fnames)): #len(psg_fnames)
  try:
    psg_f.close()
  except:
    print("psg_f does not exist")
  try:
    ann_f.close()
  except:
    print("ann_f does not exist")
  psg_f = pyedflib.EdfReader(psg_fnames[i])
  ann_f = pyedflib.EdfReader(ann_fnames[i])

  # Extract signal from the selected channel
  ch_names = psg_f.getSignalLabels()
  ch_samples = psg_f.getNSamples()
  select_ch_idx = -1
  for s in range(psg_f.signals_in_file):
    if ch_names[s] == select_ch:
      select_ch_idx = s
      break
  if select_ch_idx == -1:
    raise Exception("Channel not found.")
  n_epoch_samples = int(psg_f.getSampleFrequency(select_ch_idx) / psg_f.datarecord_duration)
  signals = psg_f.readSignal(select_ch_idx).reshape(-1, n_epoch_samples)

  ann_onsets, ann_durations, ann_stages = ann_f.readAnnotations()
  print(ann_onsets)
  print(ann_durations)
  print(ann_stages)
  print(len(ann_onsets))
  print(len(ann_durations))
  print(len(ann_stages))
  data_frame, label_frame = [], []
  for j in range(len(ann_onsets)):
    if ann_stages[j] == unknown_label:
      continue
    data_frame.append(signals[round(ann_onsets[j]):round(ann_onsets[j]+ann_durations[j])])
    label_frame.append(labeldict[ann_stages[j]])
  dataset.append(data_frame)
  label.append(label_frame)
  # Extract data and labels
  print(len(dataset[i]))
  psg_f.close()
  ann_f.close()
# Out:
# psg_f does not exist
# ann_f does not exist
# [  561.000009   581.000009   601.000009 ... 28881.000398 28901.000398
#  28921.000398]
# [19.99872  20.002626 19.99872  ... 19.99872  20.002626 19.99872 ]
# ['Sleep stage ?' 'Sleep stage ?' 'Sleep stage ?' ... 'Sleep stage W'
#  'Sleep stage W' 'Sleep stage W']
# 1419
# 1419
# 1419
# 1386
# [2.00000100e+00 2.20000010e+01 4.20000020e+01 ... 3.23020004e+04
#  3.23220004e+04 3.23420004e+04]
# [20.002626 19.99872  19.99872  ... 20.002626 19.99872  19.99872 ]
# ['Sleep stage W' 'Sleep stage W' 'Sleep stage W' ... 'Sleep stage ?'
#  'Sleep stage ?' 'Sleep stage ?']
# 1618
# 1618
# 1618
# 1557
# [2.80000010e+01 4.80000010e+01 6.80000010e+01 ... 3.04680004e+04
#  3.04880004e+04 3.05080004e+04]
# [19.99872  19.99872  19.99872  ... 20.002626 19.99872  19.99872 ]
# ['Sleep stage ?' 'Sleep stage ?' 'Sleep stage ?' ... 'Sleep stage ?'
#  'Sleep stage ?' 'Sleep stage ?']
# 1525
# 1525
# 1525
# 1507
# ...

# %%
print(len(dataset[2][1]))
print((label[0][0]))
print((dataset[0][0].shape))
print((dataset[0][1].shape))
print((dataset[1][-1].shape))
# Out:
# 20
# 0
# (20, 256)
# (20, 256)
# (20, 256)

# %%
class SleepDataset(Dataset):
    def __init__(self, dataset, label, transform=None, target_transform=None):
        self.data = dataset
        self.label = label
        self.transform = transform
        self.target_transform = target_transform

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        data = self.data[idx]
        label = self.label[idx]
        if self.transform:
            data = self.transform(data)
        if self.target_transform:
            label = self.target_transform(label)
        return data, label

# %%
temp = []
temp_label = []
for i in range(len(dataset)):
  for j in range(len(dataset[i])):
    temp.append(dataset[i][j])
    temp_label.append(label[i][j])


temp = np.array(temp)
print(temp.shape)
dataset = torch.Tensor(temp)#.transpose(1,2) # transform to torch tensor#
label = torch.Tensor(temp_label).type(torch.LongTensor)
# Out:
# (26711, 20, 256)

# %%
sleep_data = SleepDataset(dataset,label)

# %%
sleep_data.__len__()
# Out:
# 26711

# %%
sleep_data.__getitem__(333)[1]
# Out:
# tensor(3)

# %%
sleep_data.__getitem__(0)[0].shape
# Out:
# torch.Size([20, 256])

# %%
def get_data_loader(dataset, batch_size,num_workers):
  #dataset.label = dataset.type(torch.LongTensor)
  #reserve the test set
  total_train_length = int(0.85 * len(dataset)) 
  test_length = len(dataset) - total_train_length
  total_train_set, test_set = torch.utils.data.random_split(dataset, [total_train_length, test_length],generator=torch.Generator().manual_seed(100))

  #split the traning and test set
  train_length = int(0.8236 * len(total_train_set))
  val_length = len(total_train_set) - train_length
  train_set, val_set = torch.utils.data.random_split(total_train_set, [train_length, val_length],generator=torch.Generator().manual_seed(66))

  train_loader = torch.utils.data.DataLoader(train_set, batch_size=batch_size,num_workers=num_workers)
  val_loader = torch.utils.data.DataLoader(val_set, batch_size=batch_size,num_workers=num_workers)
  test_loader = torch.utils.data.DataLoader(test_set, batch_size=batch_size,num_workers=num_workers)
  
  return train_set, val_set, test_set , train_loader, val_loader, test_loader

# %%
def get_accuracy(model, dataloader):
    correct = 0
    total = 0
    for data, label in dataloader:
        #############################################
        #To Enable GPU Usage
        if use_cuda and torch.cuda.is_available():
          #print('Using Cuda')
          data = data.cuda()
          label = label.cuda()
          model = model.cuda()
         
        #############################################
        output = model(data)
        
        #select index with maximum prediction score
        pred = output.max(1, keepdim=True)[1]
        correct += pred.eq(label.view_as(pred)).sum().item()
        total += data.shape[0]
    return correct / total

# %%
def train(model, train_loader, val_loader, batch_size=64, num_epochs=1,lr=0.01):
    #train_loader = torch.utils.data.DataLoader(data, batch_size=batch_size)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(model.parameters(), lr=lr, momentum=0.9)
    #optimizer = optim.Adam(model.parameters(), lr=0.001)
    iters, losses, train_acc, val_acc = [], [], [], []

    # training
    n = 0 # the number of iterations
    for epoch in range(num_epochs):
      for data, label in iter(train_loader):
        #############################################
        #To Enable GPU Usage
        if use_cuda and torch.cuda.is_available():
          #print('Using Cuda')
          data = data.cuda()
          label = label.cuda()
          model = model.cuda()
            
        #############################################  
        out = model(data)             # forward pass
        #print('model_out:',out)
        #print('label:',label,type(label))

        #print('data:',data,data.shape)
        loss = criterion(out, label) # compute the total loss
        loss.backward()               # backward pass (compute parameter updates)
        optimizer.step()              # make the updates for each parameter
        optimizer.zero_grad()         # a clean up step for PyTorch

      # save the current training information
      iters.append(n)
      losses.append(float(loss)/batch_size)         # compute *average* loss
      train_acc.append(get_accuracy(model, train_loader)) # compute training accuracy 
      val_acc.append(get_accuracy(model, val_loader))  # compute validation accuracy
      n += 1
      print("Epoch {}".format(epoch))
      print('training accuracy: ' + str(train_acc[-1]) + ' | training loss: ' + str(float(loss)))
      print('validation accuracy: ' + str(val_acc[-1]))
    # plotting
    plt.title("Training Curve")
    plt.plot(iters, losses, label="Train")
    plt.xlabel("Iterations")
    plt.ylabel("Loss")
    plt.show()

    plt.title("Training Curve")
    plt.plot(iters, train_acc, label="Train")
    plt.plot(iters, val_acc, label="Validation")
    plt.xlabel("Iterations")
    plt.ylabel("Training Accuracy")
    plt.legend(loc='best')
    plt.show()

    print("Final Training Accuracy: {}".format(train_acc[-1]))
    print("Final Validation Accuracy: {}".format(val_acc[-1]))

# %%
from torch.nn.modules.pooling import MaxPool1d
from torch.nn.modules.batchnorm import BatchNorm1d
seq_length = 20
sampling_rate = 100
class NeuralNetwork(nn.Module):
    
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            #nn.Conv1d(in_channels=1, out_channels=128, kernel_size=sampling_rate/2, stride=sampling_rate/4, padding=0, dilation=1, groups=1, bias=True, padding_mode='zeros', device=None, dtype=None),
            nn.Conv1d(in_channels=256, out_channels=128, kernel_size=128, stride=16, padding=0, dilation=1, groups=1, bias=True, padding_mode='zeros', device=None, dtype=None),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=8,stride=8),

            nn.Conv1d(in_channels=128, out_channels=128, kernel_size=8, stride=1),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.Conv1d(in_channels=128, out_channels=128, kernel_size=8, stride=1),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.Conv1d(in_channels=128, out_channels=128, kernel_size=8, stride=1),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=4,stride=4),
            nn.Dropout(0.5) 
                 

        )

        self.lstm_layer=nn.Sequential(
            nn.LSTM(input_size=128,hidden_size=5, num_layers=1,bidirectional=False,batch_first=True ) 
        )
        self.final_use=nn.Sequential(
            nn.Dropout(0.5),
            nn.Softmax(dim=2)

        )    

    def forward(self, x):
        #x = self.flatten(x)
        #x = x.unsqueeze(1)
        x = x.transpose(1,2)
        #print(x.shape)
        #x = self.linear_relu_stack(x)
        for layer in self.linear_relu_stack:
          x = layer(x)
          #print(layer,x.shape)
      
        
        #x.reshape(x,(seq_length,-1,x.shape[-1]))
        
        #print(x.shape)
        x = self.lstm_layer(x)
        #print(len(x))
        #print(x[0].shape)
        #print(x[1])
        #print(x)
        #x.reshape(x,(-1,128))
        #print('hidden state',x[1][0])
        x = self.final_use(x[1][0])#h_0 hidden state
        x = x.squeeze(0)
        #print('final shape:',x.shape)
        #print('final x:',x)
        return x

sleep_net = NeuralNetwork()

# %%
class CNN_NeuralNetwork(nn.Module):
    
    def __init__(self):
        super(CNN_NeuralNetwork, self).__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            #nn.Conv1d(in_channels=1, out_channels=128, kernel_size=sampling_rate/2, stride=sampling_rate/4, padding=0, dilation=1, groups=1, bias=True, padding_mode='zeros', device=None, dtype=None),
            nn.Conv1d(in_channels=256, out_channels=128, kernel_size=4, stride=1, padding=0, dilation=1, groups=1, bias=True, padding_mode='zeros', device=None, dtype=None),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2,stride=2),

            nn.Conv1d(in_channels=128, out_channels=128, kernel_size=2, stride=1),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.Conv1d(in_channels=128, out_channels=64, kernel_size=2, stride=1),
            nn.BatchNorm1d(64),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2,stride=2),
            nn.Dropout(0.5) 
                 

        )

        self.final_use=nn.Sequential(
            nn.Linear(192, 5),
            nn.Softmax()

        )    

    def forward(self, x):
        print(x.shape)
        #x = self.flatten(x)
        #print(x.shape)
        #x = x.unsqueeze(1)
        x = x.transpose(1,2)
        print(x.shape)
        #x = self.linear_relu_stack(x)
        for layer in self.linear_relu_stack:
          x = layer(x)
          print(layer,x.shape)
        print('first stage done')
        #x = x.view(x.size(0),-1)
        #x = x.transpose(1,2)
        x = self.flatten(x)
        print(x.shape)
        x = self.final_use(x)

        print('final shape:',x.shape)
        print('final x:',x)
        return x

cnn_sleep_net = CNN_NeuralNetwork()

# %%
train_set, val_set, test_set , train_loader, val_loader, test_loader = get_data_loader(sleep_data,batch_size=5,num_workers=1)

# %%
train(cnn_sleep_net,train_loader, val_loader, batch_size=5, num_epochs=5,lr=0.1)
# Out:
# torch.Size([5, 20, 256])
# torch.Size([5, 256, 20])
# Conv1d(256, 128, kernel_size=(4,), stride=(1,)) torch.Size([5, 128, 17])
# BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) torch.Size([5, 128, 17])
# ReLU() torch.Size([5, 128, 17])
# MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False) torch.Size([5, 128, 8])
# Conv1d(128, 128, kernel_size=(2,), stride=(1,)) torch.Size([5, 128, 7])
# BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) torch.Size([5, 128, 7])
# ReLU() torch.Size([5, 128, 7])
# Conv1d(128, 64, kernel_size=(2,), stride=(1,)) torch.Size([5, 64, 6])
# BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) torch.Size([5, 64, 6])
# ReLU() torch.Size([5, 64, 6])
# MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False) torch.Size([5, 64, 3])
# Dropout(p=0.5, inplace=False) torch.Size([5, 64, 3])
# first stage done
# torch.Size([5, 192])
# ...

# %%
train(sleep_net,train_loader, val_loader, batch_size=5, num_epochs=20,lr=0.1)
